# %%
from util.sensor_data_util import SensorDataUtil
from constant.sensor_ID import SensorID

# %%
import os
os.getcwd()
# Out:
# 'D:\\PythonProject\\TiaoZhanBeiProject'

# %%
path = os.getcwd() + '/data/2019-05-05 22-41-37 深蹲5次.json'
path
# Out:
# 'D:\\PythonProject\\TiaoZhanBeiProject/data/2019-05-05 22-41-37 深蹲5次.json'

# %%
sdu = SensorDataUtil(path)

# %%
sdu.plot(SensorID.HOST)

# %%
sdu.plot(SensorID.SLAVE_1)
